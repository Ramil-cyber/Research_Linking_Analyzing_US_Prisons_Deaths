# %%
import pandas as pd

BJA = pd.read_csv(
    "https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data/BJA_cleaned.csv",
    low_memory=False,
)
BJS_prison = pd.read_csv(
    "https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data/BJS_cleaned.csv",
    low_memory=False,
)

# Aligning on common columns
common_cols = list(set(BJA.columns).intersection(BJS_prison.columns))
BJA = BJA[common_cols]
BJS_prison = BJS_prison[common_cols]

# Concatenating row-wise
Merged_BJA_BJS_prison = pd.concat([BJA, BJS_prison], ignore_index=True)

# Reordering columns in the specified sequence
cols_order = [
    "First_Name",
    "Last_Name",
    "Gender",
    "Race",
    "Birth_Year",
    "Reporting_Death_Year",
    "State_Name",
    "City_Name",
    "Facility_Name",
    "Death_Cause",
    "Source",
]
Merged_BJA_BJS_prison = Merged_BJA_BJS_prison[cols_order]

# %%
# Ensuring Reporting_Death_Year is integer
Merged_BJA_BJS_prison["Reporting_Death_Year"] = pd.to_numeric(
    Merged_BJA_BJS_prison["Reporting_Death_Year"], errors="coerce"
).astype("Int64")

# Sorting by Reporting_Death_Year ascending
Merged_BJA_BJS_prison = Merged_BJA_BJS_prison.sort_values(
    by="Reporting_Death_Year", ascending=True
).reset_index(drop=True)
Merged_BJA_BJS_prison
# Out:
#       First_Name   Last_Name  Gender                       Race  Birth_Year  \
# 0           Jose     Sanchez    Male         Hispanic or Latino      1927.0
# 1         Darick       Quick  Female       White (not Hispanic)      1983.0
# 2            Roy      McGraw    Male  Black or African American      1977.0
# 3          Byron      Medlin    Male       White (not Hispanic)      1960.0
# 4          Larry      Harris    Male  Black or African American      1976.0
# ...          ...         ...     ...                        ...         ...
# 42013    Vincent      Miller    Male       White (not Hispanic)      1985.0
# 42014    Richard      Hudson    Male       White (not Hispanic)      1956.0
# 42015     Thomas  Justice Jr    Male  Black or African American      1987.0
# 42016      Larry      Thomas    Male       White (not Hispanic)      1960.0
# 42017       Jack       Jones    Male  Black or African American      1986.0
#
#        Reporting_Death_Year State_Name      City_Name  \
# 0                      2015    Wyoming     Torrington
# 1                      2015    Indiana  Michigan City
# 2                      2015    Indiana    Greencastle
# 3                      2015    Indiana    Greencastle
# 4                      2015    Indiana     Plainfield
# ...                     ...        ...            ...
# 42013                  2023    Indiana    Bunker Hill
# 42014                  2023    Indiana       Carlisle
# 42015                  2023    Indiana   Indianapolis
# 42016                  2023    Indiana     Plainfield
# 42017                  2023    Alabama        Harvest
#
#                                            Facility_Name  \
# 0                            Wyoming Medium Correctional
# 1                                   Indiana State Prison
# 2                      Putnamville Correctional Facility
# 3                      Putnamville Correctional Facility
# 4                       Plainfield Correctional Facility
# ...                                                  ...
# 42013           JUDICIARY COURTS OF THE STATE OF INDIANA
# 42014           JUDICIARY COURTS OF THE STATE OF INDIANA
# 42015           JUDICIARY COURTS OF THE STATE OF INDIANA
# 42016           JUDICIARY COURTS OF THE STATE OF INDIANA
# 42017  ECONOMIC AND COMMUNITY AFFAIRS, ALABAMA DEPART...
#
#                               Death_Cause Source
# 0                                 Illness    BJS
# 1                                Homicide    BJS
# 2                                 Illness    BJS
# 3                                 Illness    BJS
# 4                                 Illness    BJS
# ...                                   ...    ...
# 42013  Unavailable, investigation pending    BJA
# 42014  Unavailable, investigation pending    BJA
# 42015                            Accident    BJA
# 42016                             Illness    BJA
# 42017                             Illness    BJA
#
# [42018 rows x 11 columns]

# %%
# Uppercasing all string values (rows) but keep column names intact
for col in Merged_BJA_BJS_prison.select_dtypes(include=["object"]).columns:
    Merged_BJA_BJS_prison[col] = Merged_BJA_BJS_prison[col].str.upper()

# Ensuring Birth_Year is integer
Merged_BJA_BJS_prison["Birth_Year"] = pd.to_numeric(
    Merged_BJA_BJS_prison["Birth_Year"], errors="coerce"
).astype("Int64")
Merged_BJA_BJS_prison

# Saving the final updated dataset
output_path = "Merged_BJA_BJS_prison.csv"
Merged_BJA_BJS_prison.to_csv(output_path, index=False)
print(f"Final dataset saved to: {output_path}")
# Out:
# Final dataset saved to: Merged_BJA_BJS_prison.csv

# %%
# Total number of records
total_records = len(Merged_BJA_BJS_prison)

# Number of unique records (across all columns)
unique_records = len(Merged_BJA_BJS_prison.drop_duplicates())

# Number of duplicate records
duplicate_records = total_records - unique_records

print(f"Total records: {total_records}")
print(f"Unique records: {unique_records}")
print(f"Duplicate records: {duplicate_records}")
# Out:
# Total records: 42018
# Unique records: 41978
# Duplicate records: 40

# %%
# Finding rows duplicated across every column
duplicates = Merged_BJA_BJS_prison[Merged_BJA_BJS_prison.duplicated(keep=False)]
duplicates
# Out:
#       First_Name Last_Name Gender                       Race  Birth_Year  \
# 16785      LARRY     MUKES   MALE  BLACK OR AFRICAN AMERICAN        1974
# 17943      LARRY     MUKES   MALE  BLACK OR AFRICAN AMERICAN        1974
# 18370        LEE    CREELY   MALE       WHITE (NOT HISPANIC)        1986
# 18637        LEE    CREELY   MALE       WHITE (NOT HISPANIC)        1986
# 22313     NATHAN     JAMES   MALE  BLACK OR AFRICAN AMERICAN        1996
# ...          ...       ...    ...                        ...         ...
# 41642    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41648    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41668    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41822    MATTHEW    BRIGGS   MALE       WHITE (NOT HISPANIC)        1981
# 41823    MATTHEW    BRIGGS   MALE       WHITE (NOT HISPANIC)        1981
#
#        Reporting_Death_Year State_Name       City_Name  \
# 16785                  2020      TEXAS          HUMBLE
# 17943                  2020      TEXAS          HUMBLE
# 18370                  2020    GEORGIA        SAVANNAH
# 18637                  2020    GEORGIA        SAVANNAH
# 22313                  2021      TEXAS          DALLAS
# ...                     ...        ...             ...
# 41642                  2023   ILLINOIS         UNKNOWN
# 41648                  2023   ILLINOIS         UNKNOWN
# 41668                  2023   ILLINOIS         UNKNOWN
# 41822                  2023       IOWA  COUNCIL BLUFFS
# 41823                  2023       IOWA  COUNCIL BLUFFS
#
#                                          Facility_Name  \
# 16785                    GOVERNOR, TEXAS OFFICE OF THE
# 17943                    GOVERNOR, TEXAS OFFICE OF THE
# 18370            CRIMINAL JUSTICE COORDINATING COUNCIL
# 18637            CRIMINAL JUSTICE COORDINATING COUNCIL
# 22313                    GOVERNOR, TEXAS OFFICE OF THE
# ...                                                ...
# 41642  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41648  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41668  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41822                               DEPT OF PUB SAFETY
# 41823                               DEPT OF PUB SAFETY
#
#                               Death_Cause Source
# 16785                             SUICIDE    BJA
# 17943                             SUICIDE    BJA
# 18370                            ACCIDENT    BJA
# 18637                            ACCIDENT    BJA
# 22313                             SUICIDE    BJA
# ...                                   ...    ...
# 41642                        USE OF FORCE    BJA
# 41648                        USE OF FORCE    BJA
# 41668  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41822                        USE OF FORCE    BJA
# 41823                        USE OF FORCE    BJA
#
# [72 rows x 11 columns]

# %%
# Computing missing counts and percentages
missing_counts = Merged_BJA_BJS_prison.isna().sum()
missing_percent = (Merged_BJA_BJS_prison.isna().mean() * 100).round(2)

# Combining into a summary DataFrame
missing_summary = pd.DataFrame(
    {"missing_count": missing_counts, "missing_percent": missing_percent}
)

print(missing_summary)
# Out:
#                       missing_count  missing_percent
# First_Name                        5             0.01
# Last_Name                         3             0.01
# Gender                           24             0.06
# Race                              0             0.00
# Birth_Year                      765             1.82
# Reporting_Death_Year              0             0.00
# State_Name                       89             0.21
# City_Name                       109             0.26
# Facility_Name                    23             0.05
# Death_Cause                     180             0.43
# Source                            0             0.00

# %%
# # 2) Identify rows with "Unknown" names (case-insensitive)
# mask_unknown = (Merged_BJA_BJS_prison['First_Name'].str.upper() == 'UNKNOWN') | (Merged_BJA_BJS_prison['Last_Name'].str.upper() == 'UNKNOWN')

# # 3) Split into known vs. unknown subsets
# df_known = Merged_BJA_BJS_prison[~mask_unknown]
# df_unknown = Merged_BJA_BJS_prison[mask_unknown]

# # 4) Drop duplicates in the known subset based on First_Name and Last_Name
# df_known = df_known.drop_duplicates(subset=['First_Name', 'Last_Name'], keep='first')

# # 5) Recombine the cleaned known subset with all unknown rows
# Cleaned_BJA_BJS_prison = pd.concat([df_known, df_unknown], ignore_index=True)

# # 6) Reset index
# Cleaned_BJA_BJS_prison.reset_index(drop=True, inplace=True)

# # 7) Save the deduplicated dataset
# output_path = 'Cleaned_BJA_BJS_prison_deduped.csv'
# Cleaned_BJA_BJS_prison.to_csv(output_path, index=False)

# # 8) Display summary
# print(f"Original rows: {len(Merged_BJA_BJS_prison)}")
# print(f"Rows after deduplication (excluding UNKNOWN): {len(Cleaned_BJA_BJS_prison)}")
# print(f"Deduplicated file saved to: {output_path}")

# %%
# 2) Identify “unknown” rows (where either first or last name is UNKNOWN)
mask_unknown = (
    Merged_BJA_BJS_prison['First_Name'].str.strip().str.upper() == 'UNKNOWN'
) | (
    Merged_BJA_BJS_prison['Last_Name'].str.strip().str.upper() == 'UNKNOWN'
)

# 3) Split into known vs. unknown subsets
df_known   = Merged_BJA_BJS_prison[~mask_unknown]
df_unknown = Merged_BJA_BJS_prison[mask_unknown]

# 4) Drop exact duplicates in the known subset (keeps first occurrence)
df_known = df_known.drop_duplicates(keep='first')

# 5) Recombine known + all unknown rows
Cleaned_BJA_BJS_prison = pd.concat([df_known, df_unknown], ignore_index=True)

# 6) (Optional) Reset index
Cleaned_BJA_BJS_prison.reset_index(drop=True, inplace=True)

# 7) Save the deduplicated file
Cleaned_BJA_BJS_prison.to_csv('Cleaned_BJA_BJS_prison.csv', index=False)
print(f"Original rows: {len(Merged_BJA_BJS_prison):,}")
print(f"Cleaned rows : {len(Cleaned_BJA_BJS_prison):,}")
# Out:
# Original rows: 42,018
# Cleaned rows : 41,993

# %%
# Finding rows duplicated across every column
duplicates = Cleaned_BJA_BJS_prison[Cleaned_BJA_BJS_prison.duplicated(keep=False)]
duplicates
# Out:
#       First_Name Last_Name Gender                       Race  Birth_Year  \
# 41939    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41945    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41946    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41947    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41948    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41949    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41954    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41955    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41956    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41958    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41959    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41966    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41970    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41972    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41973    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41974    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41975    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41985    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41986    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41988    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41990    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41991    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
#
#        Reporting_Death_Year State_Name City_Name  \
# 41939                  2022   ILLINOIS   UNKNOWN
# 41945                  2022   ILLINOIS   UNKNOWN
# 41946                  2022   ILLINOIS   UNKNOWN
# 41947                  2022   ILLINOIS   UNKNOWN
# 41948                  2022   ILLINOIS   UNKNOWN
# 41949                  2022   ILLINOIS   UNKNOWN
# 41954                  2022   ILLINOIS   UNKNOWN
# 41955                  2022   ILLINOIS   UNKNOWN
# 41956                  2022   ILLINOIS   UNKNOWN
# 41958                  2022   ILLINOIS   UNKNOWN
# 41959                  2022   ILLINOIS   UNKNOWN
# 41966                  2023   ILLINOIS   UNKNOWN
# 41970                  2023   ILLINOIS   UNKNOWN
# 41972                  2023   ILLINOIS   UNKNOWN
# 41973                  2023   ILLINOIS   UNKNOWN
# 41974                  2023   ILLINOIS   UNKNOWN
# 41975                  2023   ILLINOIS   UNKNOWN
# 41985                  2023   ILLINOIS   UNKNOWN
# 41986                  2023   ILLINOIS   UNKNOWN
# 41988                  2023   ILLINOIS   UNKNOWN
# 41990                  2023   ILLINOIS   UNKNOWN
# 41991                  2023   ILLINOIS   UNKNOWN
#
#                                          Facility_Name  \
# 41939  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41945  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41946  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41947  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41948  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41949  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41954  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41955  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41956  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41958  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41959  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41966  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41970  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41972  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41973  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41974  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41975  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41985  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41986  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41988  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41990  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41991  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
#
#                               Death_Cause Source
# 41939  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41945  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41946                             SUICIDE    BJA
# 41947                             SUICIDE    BJA
# 41948                        USE OF FORCE    BJA
# 41949                        USE OF FORCE    BJA
# 41954  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41955  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41956  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41958                             SUICIDE    BJA
# 41959  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41966                        USE OF FORCE    BJA
# 41970                        USE OF FORCE    BJA
# 41972                             SUICIDE    BJA
# 41973                             SUICIDE    BJA
# 41974                             SUICIDE    BJA
# 41975                             SUICIDE    BJA
# 41985                             SUICIDE    BJA
# 41986  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41988                        USE OF FORCE    BJA
# 41990                        USE OF FORCE    BJA
# 41991  UNAVAILABLE, INVESTIGATION PENDING    BJA

# %%
# ------------------------------------------------------------------
# 2) Filter to years 2015–2022 (exclude 2023)
# ------------------------------------------------------------------
df_filtered = Cleaned_BJA_BJS_prison[Cleaned_BJA_BJS_prison['Reporting_Death_Year'].between(2015, 2022)]

# ------------------------------------------------------------------
# 3) Summarize total deaths by year and state
# ------------------------------------------------------------------
summary = (
    df_filtered
    .groupby(['Reporting_Death_Year', 'State_Name'], as_index=False)
    .size()
    .rename(columns={
        'Reporting_Death_Year': 'Year',
        'State_Name': 'State',
        'size': 'Deaths'
    })
    .sort_values(['Year', 'State'])
)

# ------------------------------------------------------------------
# 4) Save the summary as a new CSV
# ------------------------------------------------------------------
output_path = 'Cleaned_BJA_BJS_prison_deaths_by_state_year_2015_2022.csv'
summary.to_csv(output_path, index=False)

# ------------------------------------------------------------------
# 5) Confirmation
# ------------------------------------------------------------------
print(f"Saved deaths‐by‐state‐and‐year summary to:\n{output_path}")
summary.head(10)
# Out:
# Saved deaths‐by‐state‐and‐year summary to:
# Cleaned_BJA_BJS_prison_deaths_by_state_year_2015_2022.csv
#    Year        State  Deaths
# 0  2015      ALABAMA      20
# 1  2015       ALASKA       3
# 2  2015      ARIZONA      26
# 3  2015     ARKANSAS      14
# 4  2015   CALIFORNIA      79
# 5  2015     COLORADO      19
# 6  2015  CONNECTICUT       4
# 7  2015     DELAWARE       3
# 8  2015      FLORIDA      96
# 9  2015      GEORGIA      31
