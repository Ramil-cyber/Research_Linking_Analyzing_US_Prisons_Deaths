# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

BJA = pd.read_csv(
    "https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data/BJA_cleaned.csv",
    low_memory=False,
)
BJS_prison = pd.read_csv(
    "https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data/BJS_cleaned.csv",
    low_memory=False,
)

# Aligning on common columns
common_cols = list(set(BJA.columns).intersection(BJS_prison.columns))
BJA = BJA[common_cols]
BJS_prison = BJS_prison[common_cols]

# Concatenating row-wise
Merged_BJA_BJS_prison = pd.concat([BJA, BJS_prison], ignore_index=True)

# Reordering columns in the specified sequence
cols_order = [
    "First_Name",
    "Last_Name",
    "Gender",
    "Race",
    "Birth_Year",
    "Reporting_Death_Year",
    "State_Name",
    "City_Name",
    "Facility_Name",
    "Death_Cause",
    "Source",
]
Merged_BJA_BJS_prison = Merged_BJA_BJS_prison[cols_order]

# %%
# Ensuring Reporting_Death_Year is integer
Merged_BJA_BJS_prison["Reporting_Death_Year"] = pd.to_numeric(
    Merged_BJA_BJS_prison["Reporting_Death_Year"], errors="coerce"
).astype("Int64")

# Sorting by Reporting_Death_Year ascending
Merged_BJA_BJS_prison = Merged_BJA_BJS_prison.sort_values(
    by="Reporting_Death_Year", ascending=True
).reset_index(drop=True)
Merged_BJA_BJS_prison
# Out:
#       First_Name   Last_Name Gender                       Race  Birth_Year  \
# 0           Jose     Sanchez   Male         Hispanic or Latino      1927.0
# 1        Ernesto      Nieves   Male         Hispanic or Latino      1964.0
# 2        Francis      Soffen   Male       White (not Hispanic)      1939.0
# 3        Kenneth    Getchell   Male       White (not Hispanic)      1931.0
# 4         Alfred     Trudell   Male       White (not Hispanic)      1942.0
# ...          ...         ...    ...                        ...         ...
# 42013    Brandon  Stephenson   Male  Black or African American      1994.0
# 42014     Joseph  Bennet Jr.   Male       White (not Hispanic)      1981.0
# 42015    Anthony       Starr   Male       White (not Hispanic)      1943.0
# 42016     Joseph    Williams   Male  Black or African American      1952.0
# 42017      Kerry     Mallard   Male       White (not Hispanic)      1966.0
#
#        Reporting_Death_Year     State_Name    City_Name  \
# 0                      2015        Wyoming   Torrington
# 1                      2015  Massachusetts  Bridgewater
# 2                      2015  Massachusetts      Shirley
# 3                      2015  Massachusetts      Shirley
# 4                      2015  Massachusetts      Shirley
# ...                     ...            ...          ...
# 42013                  2023           Ohio     COLUMBUS
# 42014                  2023           Ohio     Columbus
# 42015                  2023           Ohio      Grafton
# 42016                  2023           Ohio     COLUMBUS
# 42017                  2023      Tennessee    Pikeville
#
#                                            Facility_Name Death_Cause Source
# 0                            Wyoming Medium Correctional     Illness    BJS
# 1                                  Bwater State Hospital     Illness    BJS
# 2                                            MCI Shirley     Illness    BJS
# 3                                            MCI Shirley     Illness    BJS
# 4                                            MCI Shirley     Illness    BJS
# ...                                                  ...         ...    ...
# 42013           Ohio Office of Criminal Justice Services     Illness    BJA
# 42014           Ohio Office of Criminal Justice Services     Illness    BJA
# 42015           Ohio Office of Criminal Justice Services     Illness    BJA
# 42016           Ohio Office of Criminal Justice Services     Illness    BJA
# 42017  FINANCE AND ADMINISTRATION, TENNESSEE DEPARTME...     Illness    BJA
#
# [42018 rows x 11 columns]

# %%
# Uppercasing all string values (rows) but keep column names intact
for col in Merged_BJA_BJS_prison.select_dtypes(include=["object"]).columns:
    Merged_BJA_BJS_prison[col] = Merged_BJA_BJS_prison[col].str.upper()

# Ensuring Birth_Year is integer
Merged_BJA_BJS_prison["Birth_Year"] = pd.to_numeric(
    Merged_BJA_BJS_prison["Birth_Year"], errors="coerce"
).astype("Int64")
Merged_BJA_BJS_prison

# Saving the final updated dataset
# output_path = "Merged_BJA_BJS_prison.csv"
# Merged_BJA_BJS_prison.to_csv(output_path, index=False)
# print(f"Final dataset saved to: {output_path}")
# Out:
#       First_Name   Last_Name Gender                       Race  Birth_Year  \
# 0           JOSE     SANCHEZ   MALE         HISPANIC OR LATINO        1927
# 1        ERNESTO      NIEVES   MALE         HISPANIC OR LATINO        1964
# 2        FRANCIS      SOFFEN   MALE       WHITE (NOT HISPANIC)        1939
# 3        KENNETH    GETCHELL   MALE       WHITE (NOT HISPANIC)        1931
# 4         ALFRED     TRUDELL   MALE       WHITE (NOT HISPANIC)        1942
# ...          ...         ...    ...                        ...         ...
# 42013    BRANDON  STEPHENSON   MALE  BLACK OR AFRICAN AMERICAN        1994
# 42014     JOSEPH  BENNET JR.   MALE       WHITE (NOT HISPANIC)        1981
# 42015    ANTHONY       STARR   MALE       WHITE (NOT HISPANIC)        1943
# 42016     JOSEPH    WILLIAMS   MALE  BLACK OR AFRICAN AMERICAN        1952
# 42017      KERRY     MALLARD   MALE       WHITE (NOT HISPANIC)        1966
#
#        Reporting_Death_Year     State_Name    City_Name  \
# 0                      2015        WYOMING   TORRINGTON
# 1                      2015  MASSACHUSETTS  BRIDGEWATER
# 2                      2015  MASSACHUSETTS      SHIRLEY
# 3                      2015  MASSACHUSETTS      SHIRLEY
# 4                      2015  MASSACHUSETTS      SHIRLEY
# ...                     ...            ...          ...
# 42013                  2023           OHIO     COLUMBUS
# 42014                  2023           OHIO     COLUMBUS
# 42015                  2023           OHIO      GRAFTON
# 42016                  2023           OHIO     COLUMBUS
# 42017                  2023      TENNESSEE    PIKEVILLE
#
#                                            Facility_Name Death_Cause Source
# 0                            WYOMING MEDIUM CORRECTIONAL     ILLNESS    BJS
# 1                                  BWATER STATE HOSPITAL     ILLNESS    BJS
# 2                                            MCI SHIRLEY     ILLNESS    BJS
# 3                                            MCI SHIRLEY     ILLNESS    BJS
# 4                                            MCI SHIRLEY     ILLNESS    BJS
# ...                                                  ...         ...    ...
# 42013           OHIO OFFICE OF CRIMINAL JUSTICE SERVICES     ILLNESS    BJA
# 42014           OHIO OFFICE OF CRIMINAL JUSTICE SERVICES     ILLNESS    BJA
# 42015           OHIO OFFICE OF CRIMINAL JUSTICE SERVICES     ILLNESS    BJA
# 42016           OHIO OFFICE OF CRIMINAL JUSTICE SERVICES     ILLNESS    BJA
# 42017  FINANCE AND ADMINISTRATION, TENNESSEE DEPARTME...     ILLNESS    BJA
#
# [42018 rows x 11 columns]

# %%
# Total number of records
total_records = len(Merged_BJA_BJS_prison)

# Number of unique records (across all columns)
unique_records = len(Merged_BJA_BJS_prison.drop_duplicates())

# Number of duplicate records
duplicate_records = total_records - unique_records

print(f"Total records: {total_records}")
print(f"Unique records: {unique_records}")
print(f"Duplicate records: {duplicate_records}")
# Out:
# Total records: 42018
# Unique records: 41978
# Duplicate records: 40

# %%
# Finding rows duplicated across every column
duplicates = Merged_BJA_BJS_prison[Merged_BJA_BJS_prison.duplicated(keep=False)]
duplicates
# Out:
#       First_Name Last_Name Gender                       Race  Birth_Year  \
# 16683      LARRY     MUKES   MALE  BLACK OR AFRICAN AMERICAN        1974
# 16722      LARRY     MUKES   MALE  BLACK OR AFRICAN AMERICAN        1974
# 20196        LEE    CREELY   MALE       WHITE (NOT HISPANIC)        1986
# 21385        LEE    CREELY   MALE       WHITE (NOT HISPANIC)        1986
# 22663      BRUCE    LESLIE   MALE       WHITE (NOT HISPANIC)        1952
# ...          ...       ...    ...                        ...         ...
# 36702    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 36933    MATTHEW    BRIGGS   MALE       WHITE (NOT HISPANIC)        1981
# 36970    MATTHEW    BRIGGS   MALE       WHITE (NOT HISPANIC)        1981
# 39155       ERIC    REAVES   MALE  BLACK OR AFRICAN AMERICAN        1969
# 39205       ERIC    REAVES   MALE  BLACK OR AFRICAN AMERICAN        1969
#
#        Reporting_Death_Year    State_Name       City_Name  \
# 16683                  2020         TEXAS          HUMBLE
# 16722                  2020         TEXAS          HUMBLE
# 20196                  2020       GEORGIA        SAVANNAH
# 21385                  2020       GEORGIA        SAVANNAH
# 22663                  2021       WYOMING      TORRINGTON
# ...                     ...           ...             ...
# 36702                  2023      ILLINOIS         UNKNOWN
# 36933                  2023          IOWA  COUNCIL BLUFFS
# 36970                  2023          IOWA  COUNCIL BLUFFS
# 39155                  2023  PENNSYLVANIA   COAL TOWNSHIP
# 39205                  2023  PENNSYLVANIA   COAL TOWNSHIP
#
#                                          Facility_Name   Death_Cause Source
# 16683                    GOVERNOR, TEXAS OFFICE OF THE       SUICIDE    BJA
# 16722                    GOVERNOR, TEXAS OFFICE OF THE       SUICIDE    BJA
# 20196            CRIMINAL JUSTICE COORDINATING COUNCIL      ACCIDENT    BJA
# 21385            CRIMINAL JUSTICE COORDINATING COUNCIL      ACCIDENT    BJA
# 22663                      ATTORNEY GENERAL OF WYOMING       ILLNESS    BJA
# ...                                                ...           ...    ...
# 36702  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY  USE OF FORCE    BJA
# 36933                               DEPT OF PUB SAFETY  USE OF FORCE    BJA
# 36970                               DEPT OF PUB SAFETY  USE OF FORCE    BJA
# 39155             CRIME & DELINQUENCY PA COMMISSION ON       ILLNESS    BJA
# 39205             CRIME & DELINQUENCY PA COMMISSION ON       ILLNESS    BJA
#
# [72 rows x 11 columns]

# %%
# Computing missing counts and percentages
missing_counts = Merged_BJA_BJS_prison.isna().sum()
missing_percent = (Merged_BJA_BJS_prison.isna().mean() * 100).round(2)

# Combining into a summary DataFrame
missing_summary = pd.DataFrame(
    {"missing_count": missing_counts, "missing_percent": missing_percent}
)

print(missing_summary)
# Out:
#                       missing_count  missing_percent
# First_Name                        5             0.01
# Last_Name                         3             0.01
# Gender                           24             0.06
# Race                              0             0.00
# Birth_Year                      765             1.82
# Reporting_Death_Year              0             0.00
# State_Name                       89             0.21
# City_Name                       109             0.26
# Facility_Name                    23             0.05
# Death_Cause                     180             0.43
# Source                            0             0.00

# %%
# # 2) Identify rows with "Unknown" names (case-insensitive)
# mask_unknown = (Merged_BJA_BJS_prison['First_Name'].str.upper() == 'UNKNOWN') | (Merged_BJA_BJS_prison['Last_Name'].str.upper() == 'UNKNOWN')

# # 3) Split into known vs. unknown subsets
# df_known = Merged_BJA_BJS_prison[~mask_unknown]
# df_unknown = Merged_BJA_BJS_prison[mask_unknown]

# # 4) Drop duplicates in the known subset based on First_Name and Last_Name
# df_known = df_known.drop_duplicates(subset=['First_Name', 'Last_Name'], keep='first')

# # 5) Recombine the cleaned known subset with all unknown rows
# Cleaned_BJA_BJS_prison = pd.concat([df_known, df_unknown], ignore_index=True)

# # 6) Reset index
# Cleaned_BJA_BJS_prison.reset_index(drop=True, inplace=True)

# # 7) Save the deduplicated dataset
# output_path = 'Cleaned_BJA_BJS_prison_deduped.csv'
# Cleaned_BJA_BJS_prison.to_csv(output_path, index=False)

# # 8) Display summary
# print(f"Original rows: {len(Merged_BJA_BJS_prison)}")
# print(f"Rows after deduplication (excluding UNKNOWN): {len(Cleaned_BJA_BJS_prison)}")
# print(f"Deduplicated file saved to: {output_path}")

# %%
# 2) Identify “unknown” rows (where either first or last name is UNKNOWN)
mask_unknown = (
    Merged_BJA_BJS_prison["First_Name"].str.strip().str.upper() == "UNKNOWN"
) | (Merged_BJA_BJS_prison["Last_Name"].str.strip().str.upper() == "UNKNOWN")

# 3) Split into known vs. unknown subsets
df_known = Merged_BJA_BJS_prison[~mask_unknown]
df_unknown = Merged_BJA_BJS_prison[mask_unknown]

# 4) Drop exact duplicates in the known subset (keeps first occurrence)
df_known = df_known.drop_duplicates(keep="first")

# 5) Recombine known + all unknown rows
Cleaned_BJA_BJS_prison = pd.concat([df_known, df_unknown], ignore_index=True)

# 6) (Optional) Reset index
Cleaned_BJA_BJS_prison.reset_index(drop=True, inplace=True)

# 7) Save the deduplicated file
# Cleaned_BJA_BJS_prison.to_csv('Cleaned_BJA_BJS_prison.csv', index=False)
# print(f"Original rows: {len(Merged_BJA_BJS_prison):,}")
# print(f"Cleaned rows : {len(Cleaned_BJA_BJS_prison):,}")

# %%
# Finding rows duplicated across every column
duplicates = Cleaned_BJA_BJS_prison[Cleaned_BJA_BJS_prison.duplicated(keep=False)]
duplicates
# Out:
#       First_Name Last_Name Gender                       Race  Birth_Year  \
# 41940    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41943    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41944    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41946    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41947    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41949    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41950    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41951    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41952    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41953    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41954    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41965    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41966    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41968    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41969    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41970    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41971    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41976    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41978    UNKNOWN   UNKNOWN   MALE       WHITE (NOT HISPANIC)        <NA>
# 41979    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41983    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
# 41984    UNKNOWN   UNKNOWN   MALE  BLACK OR AFRICAN AMERICAN        <NA>
#
#        Reporting_Death_Year State_Name City_Name  \
# 41940                  2022   ILLINOIS   UNKNOWN
# 41943                  2022   ILLINOIS   UNKNOWN
# 41944                  2022   ILLINOIS   UNKNOWN
# 41946                  2022   ILLINOIS   UNKNOWN
# 41947                  2022   ILLINOIS   UNKNOWN
# 41949                  2022   ILLINOIS   UNKNOWN
# 41950                  2022   ILLINOIS   UNKNOWN
# 41951                  2022   ILLINOIS   UNKNOWN
# 41952                  2022   ILLINOIS   UNKNOWN
# 41953                  2022   ILLINOIS   UNKNOWN
# 41954                  2022   ILLINOIS   UNKNOWN
# 41965                  2023   ILLINOIS   UNKNOWN
# 41966                  2023   ILLINOIS   UNKNOWN
# 41968                  2023   ILLINOIS   UNKNOWN
# 41969                  2023   ILLINOIS   UNKNOWN
# 41970                  2023   ILLINOIS   UNKNOWN
# 41971                  2023   ILLINOIS   UNKNOWN
# 41976                  2023   ILLINOIS   UNKNOWN
# 41978                  2023   ILLINOIS   UNKNOWN
# 41979                  2023   ILLINOIS   UNKNOWN
# 41983                  2023   ILLINOIS   UNKNOWN
# 41984                  2023   ILLINOIS   UNKNOWN
#
#                                          Facility_Name  \
# 41940  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41943  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41944  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41946  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41947  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41949  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41950  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41951  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41952  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41953  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41954  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41965  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41966  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41968  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41969  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41970  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41971  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41976  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41978  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41979  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41983  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
# 41984  ILLINOIS CRIMINAL JUSTICE INFORMATION AUTHORITY
#
#                               Death_Cause Source
# 41940                        USE OF FORCE    BJA
# 41943                        USE OF FORCE    BJA
# 41944  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41946  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41947                             SUICIDE    BJA
# 41949                             SUICIDE    BJA
# 41950                             SUICIDE    BJA
# 41951  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41952  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41953  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41954  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41965                             SUICIDE    BJA
# 41966  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41968                             SUICIDE    BJA
# 41969                             SUICIDE    BJA
# 41970                             SUICIDE    BJA
# 41971                             SUICIDE    BJA
# 41976                        USE OF FORCE    BJA
# 41978  UNAVAILABLE, INVESTIGATION PENDING    BJA
# 41979                        USE OF FORCE    BJA
# 41983                        USE OF FORCE    BJA
# 41984                        USE OF FORCE    BJA

# %%
# ------------------------------------------------------------------
# 2) Aggregate number of deaths by state
# ------------------------------------------------------------------
state_counts = (
    Cleaned_BJA_BJS_prison.groupby("State_Name").size().reset_index(name="Deaths")
)

# ------------------------------------------------------------------
# 3) Prepare mapping from uppercase full state names to USPS codes
# ------------------------------------------------------------------
full_to_abbr = {
    "ALABAMA": "AL",
    "ALASKA": "AK",
    "ARIZONA": "AZ",
    "ARKANSAS": "AR",
    "CALIFORNIA": "CA",
    "COLORADO": "CO",
    "CONNECTICUT": "CT",
    "DELAWARE": "DE",
    "DISTRICT OF COLUMBIA": "DC",
    "FLORIDA": "FL",
    "GEORGIA": "GA",
    "HAWAII": "HI",
    "IDAHO": "ID",
    "ILLINOIS": "IL",
    "INDIANA": "IN",
    "IOWA": "IA",
    "KANSAS": "KS",
    "KENTUCKY": "KY",
    "LOUISIANA": "LA",
    "MAINE": "ME",
    "MARYLAND": "MD",
    "MASSACHUSETTS": "MA",
    "MICHIGAN": "MI",
    "MINNESOTA": "MN",
    "MISSISSIPPI": "MS",
    "MISSOURI": "MO",
    "MONTANA": "MT",
    "NEBRASKA": "NE",
    "NEVADA": "NV",
    "NEW HAMPSHIRE": "NH",
    "NEW JERSEY": "NJ",
    "NEW MEXICO": "NM",
    "NEW YORK": "NY",
    "NORTH CAROLINA": "NC",
    "NORTH DAKOTA": "ND",
    "OHIO": "OH",
    "OKLAHOMA": "OK",
    "OREGON": "OR",
    "PENNSYLVANIA": "PA",
    "RHODE ISLAND": "RI",
    "SOUTH CAROLINA": "SC",
    "SOUTH DAKOTA": "SD",
    "TENNESSEE": "TN",
    "TEXAS": "TX",
    "UTAH": "UT",
    "VERMONT": "VT",
    "VIRGINIA": "VA",
    "WASHINGTON": "WA",
    "WEST VIRGINIA": "WV",
    "WISCONSIN": "WI",
    "WYOMING": "WY",
}

# Map each state name to its USPS code
state_counts["abbr"] = state_counts["State_Name"].str.upper().map(full_to_abbr)

# ------------------------------------------------------------------
# 4) State centroids for label overlay
# ------------------------------------------------------------------
state_centroids = {
    "AL": {"lat": 32.8067, "lon": -86.7911},
    "AK": {"lat": 61.3707, "lon": -152.4044},
    "AZ": {"lat": 33.7298, "lon": -111.4312},
    "AR": {"lat": 34.9697, "lon": -92.3731},
    "CA": {"lat": 36.1162, "lon": -119.6816},
    "CO": {"lat": 39.0598, "lon": -105.3111},
    "CT": {"lat": 41.5978, "lon": -72.7554},
    "DE": {"lat": 39.3185, "lon": -75.5071},
    "DC": {"lat": 38.8974, "lon": -77.0268},
    "FL": {"lat": 27.7663, "lon": -81.6868},
    "GA": {"lat": 33.0406, "lon": -83.6431},
    "HI": {"lat": 21.0943, "lon": -157.4983},
    "ID": {"lat": 44.2405, "lon": -114.4788},
    "IL": {"lat": 40.3495, "lon": -88.9861},
    "IN": {"lat": 39.8494, "lon": -86.2583},
    "IA": {"lat": 42.0115, "lon": -93.2105},
    "KS": {"lat": 38.5266, "lon": -96.7265},
    "KY": {"lat": 37.6681, "lon": -84.6701},
    "LA": {"lat": 31.1695, "lon": -91.8678},
    "ME": {"lat": 44.6939, "lon": -69.3819},
    "MD": {"lat": 39.0639, "lon": -76.8021},
    "MA": {"lat": 42.2302, "lon": -71.5301},
    "MI": {"lat": 43.3266, "lon": -84.5361},
    "MN": {"lat": 45.6945, "lon": -93.9002},
    "MS": {"lat": 32.7416, "lon": -89.6787},
    "MO": {"lat": 38.4561, "lon": -92.2884},
    "MT": {"lat": 46.9219, "lon": -110.4544},
    "NE": {"lat": 41.1254, "lon": -98.2681},
    "NV": {"lat": 38.3135, "lon": -117.0554},
    "NH": {"lat": 43.4525, "lon": -71.5639},
    "NJ": {"lat": 40.2989, "lon": -74.5210},
    "NM": {"lat": 34.8405, "lon": -106.2485},
    "NY": {"lat": 42.1657, "lon": -74.9481},
    "NC": {"lat": 35.6301, "lon": -79.8064},
    "ND": {"lat": 47.5289, "lon": -99.7840},
    "OH": {"lat": 40.3888, "lon": -82.7649},
    "OK": {"lat": 35.5653, "lon": -96.9289},
    "OR": {"lat": 44.5720, "lon": -122.0709},
    "PA": {"lat": 40.5908, "lon": -77.2098},
    "RI": {"lat": 41.6809, "lon": -71.5118},
    "SC": {"lat": 33.8569, "lon": -80.9450},
    "SD": {"lat": 44.2998, "lon": -99.4388},
    "TN": {"lat": 35.7478, "lon": -86.6923},
    "TX": {"lat": 31.0545, "lon": -97.5635},
    "UT": {"lat": 40.1500, "lon": -111.8624},
    "VT": {"lat": 44.0459, "lon": -72.7107},
    "VA": {"lat": 37.7693, "lon": -78.1699},
    "WA": {"lat": 47.4009, "lon": -121.4905},
    "WV": {"lat": 38.4912, "lon": -80.9545},
    "WI": {"lat": 44.2685, "lon": -89.6165},
    "WY": {"lat": 42.7560, "lon": -107.3025},
}
# Attach lat/lon to the DataFrame
state_counts["lat"] = state_counts["abbr"].map(lambda s: state_centroids[s]["lat"])
state_counts["lon"] = state_counts["abbr"].map(lambda s: state_centroids[s]["lon"])

# ------------------------------------------------------------------
# 5) Create the choropleth map
# ------------------------------------------------------------------
fig = px.choropleth(
    state_counts,
    locations="abbr",
    locationmode="USA-states",
    color="Deaths",
    hover_name="State_Name",
    hover_data={"Deaths": True, "abbr": False},
    scope="usa",
    color_continuous_scale="Reds",
    labels={"Deaths": "Prisoner Deaths"},
    title="US Prisoner Deaths by State",
)

# ------------------------------------------------------------------
# 6) Overlay state abbreviations without hoverinfo
# ------------------------------------------------------------------
fig.add_trace(
    go.Scattergeo(
        lon=state_counts["lon"],
        lat=state_counts["lat"],
        text=state_counts["abbr"],
        mode="text",
        showlegend=False,
        hoverinfo="none",
        textfont=dict(size=10, color="black"),
    )
)

# ------------------------------------------------------------------
# 7) Final layout tweaks
# ------------------------------------------------------------------
fig.update_layout(
    geo=dict(lakecolor="white", bgcolor="#F0F0F0"), margin=dict(l=0, r=0, t=50, b=0)
)

# ------------------------------------------------------------------
# 8) Export HTML and display
# ------------------------------------------------------------------
fig.write_html("prisoner_deaths_map_with_labels.html", include_plotlyjs="cdn")
fig.show()

# %%
import pandas as pd

Prison_pop = pd.read_csv(
    "https://raw.githubusercontent.com/vera-institute/incarceration-trends/refs/heads/main/incarceration_trends_state.csv"
)
Prison_pop
# Out:
#       year state_abbr state_name  state_fips region  division  \
# 0     2024         AK     Alaska           2   West   Pacific
# 1     2023         AK     Alaska           2   West   Pacific
# 2     2022         AK     Alaska           2   West   Pacific
# 3     2021         AK     Alaska           2   West   Pacific
# 4     2020         AK     Alaska           2   West   Pacific
# ...    ...        ...        ...         ...    ...       ...
# 3526  1962         WY    Wyoming          56   West  Mountain
# 3527  1961         WY    Wyoming          56   West  Mountain
# 3528  1960         WY    Wyoming          56   West  Mountain
# 3529  1955         WY    Wyoming          56   West  Mountain
# 3530  1950         WY    Wyoming          56   West  Mountain
#
#       total_pop_15to64  female_pop_15to64  male_pop_15to64  aapi_pop_15to64  \
# 0             484376.0           224281.0         260095.0          44427.0
# 1             484376.0           224281.0         260095.0          44427.0
# 2             484376.0           224281.0         260095.0          44427.0
# 3             486916.0           225591.0         261325.0          44109.0
# 4             488623.0           226819.0         261804.0          43920.0
# ...                ...                ...              ...              ...
# 3526               NaN                NaN              NaN              NaN
# 3527               NaN                NaN              NaN              NaN
# 3528               NaN                NaN              NaN              NaN
# 3529               NaN                NaN              NaN              NaN
# 3530               NaN                NaN              NaN              NaN
#
#       ...  aapi_female_prison_adm_rate  black_female_prison_adm_rate  \
# 0     ...                          NaN                           NaN
# 1     ...                          NaN                           NaN
# 2     ...                          NaN                           NaN
# 3     ...                          NaN                           NaN
# 4     ...                          NaN                           NaN
# ...   ...                          ...                           ...
# 3526  ...                          NaN                           NaN
# 3527  ...                          NaN                           NaN
# 3528  ...                          NaN                           NaN
# 3529  ...                          NaN                           NaN
# 3530  ...                          NaN                           NaN
#
#       latinx_female_prison_adm_rate  native_female_prison_adm_rate  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 3526                            NaN                            NaN
# 3527                            NaN                            NaN
# 3528                            NaN                            NaN
# 3529                            NaN                            NaN
# 3530                            NaN                            NaN
#
#       white_female_prison_adm_rate  aapi_male_prison_adm_rate  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 3526                           NaN                        NaN
# 3527                           NaN                        NaN
# 3528                           NaN                        NaN
# 3529                           NaN                        NaN
# 3530                           NaN                        NaN
#
#       black_male_prison_adm_rate  latinx_male_prison_adm_rate  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 3526                         NaN                          NaN
# 3527                         NaN                          NaN
# 3528                         NaN                          NaN
# 3529                         NaN                          NaN
# 3530                         NaN                          NaN
#
#       native_male_prison_adm_rate  white_male_prison_adm_rate
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 3526                          NaN                         NaN
# 3527                          NaN                         NaN
# 3528                          NaN                         NaN
# 3529                          NaN                         NaN
# 3530                          NaN                         NaN
#
# [3531 rows x 123 columns]

# %%
# ------------------------------------------------------------------
# 2) Define columns to keep
# ------------------------------------------------------------------
keep_cols = [
    "year",
    "state_abbr",
    "state_name",
    "state_fips",
    "region",
    "division",
    "total_pop_15to64",
    "female_pop_15to64",
    "male_pop_15to64",
    "aapi_pop_15to64",
    "black_pop_15to64",
    "latinx_pop_15to64",
    "native_pop_15to64",
    "white_pop_15to64",
    "aapi_female_pop_15to64",
    "black_female_pop_15to64",
    "latinx_female_pop_15to64",
    "native_female_pop_15to64",
    "white_female_pop_15to64",
    "aapi_male_pop_15to64",
    "black_male_pop_15to64",
    "latinx_male_pop_15to64",
    "native_male_pop_15to64",
    "white_male_pop_15to64",
    "total_incarceration",
    "total_incarceration_rate",
    "held_in_jail",
    "total_jail_pop",
    "female_jail_pop",
    "male_jail_pop",
    "total_jail_pop_rate",
    "female_jail_pop_rate",
    "male_jail_pop_rate",
    "total_prison_pop",
    "female_prison_pop",
    "male_prison_pop",
    "total_prison_pop_rate",
    "female_prison_pop_rate",
    "male_prison_pop_rate",
]

# ------------------------------------------------------------------
# 3) Subset to the selected columns
# ------------------------------------------------------------------
Prison_pop_reduced = Prison_pop[keep_cols]

# ------------------------------------------------------------------
# 4) Filter to years 2015–2022
# ------------------------------------------------------------------
Prison_pop_reduced = Prison_pop_reduced[Prison_pop_reduced["year"].between(2015, 2022)]

# # ------------------------------------------------------------------
# # 5) Sum 'held_in_jail' into 'total_jail_pop'
# # ------------------------------------------------------------------
# Prison_pop_reduced["total_jail_pop"] = (
#     Prison_pop_reduced["total_jail_pop"] + Prison_pop_reduced["held_in_jail"]
# )

# # ------------------------------------------------------------------
# # 6) Remove the 'held_in_jail' column entirely
# # ------------------------------------------------------------------
# Prison_pop_reduced = Prison_pop_reduced.drop(columns=["held_in_jail"])

# # ------------------------------------------------------------------
# # 7) Save the final processed dataset
# # ------------------------------------------------------------------
# output_path = "Prison_population_2015_2022.csv"
# Prison_pop_reduced.to_csv(output_path, index=False)

# ------------------------------------------------------------------
# 8) Confirmation
# ------------------------------------------------------------------
# print(
#     f"Processed data (years 2015–2022) with held_in_jail summed into total_jail_pop "
#     f"and held_in_jail dropped. Saved to:\n{output_path}"
# )
print(Prison_pop_reduced[["year", "state_abbr", "total_jail_pop"]].head())
# Out:
#    year state_abbr  total_jail_pop
# 2  2022         AK          2934.0
# 3  2021         AK          3076.0
# 4  2020         AK          2784.0
# 5  2019         AK          2693.0
# 6  2018         AK          2441.0

# %%
# 2) Create total female and male incarcerated population columns
Prison_pop_reduced["female_total"] = (
    Prison_pop_reduced["female_jail_pop"] + Prison_pop_reduced["female_prison_pop"]
)
Prison_pop_reduced["male_total"] = (
    Prison_pop_reduced["male_jail_pop"] + Prison_pop_reduced["male_prison_pop"]
)

# 3) Compute race-specific population percentages
races = ["aapi", "black", "latinx", "native", "white"]
for race in races:
    pop_col = f"{race}_pop_15to64"
    pct_col = f"{race}_pct"
    Prison_pop_reduced[pct_col] = round(
        Prison_pop_reduced[pop_col] / Prison_pop_reduced["total_pop_15to64"] * 100, 2
    )

# 4) Reorder to insert new columns next to their related fields
new_order = []
for col in Prison_pop_reduced.columns:
    new_order.append(col)
    # after jail/prison pop totals, insert female_total/male_total
    if col == "female_prison_pop":
        new_order.append("female_total")
    if col == "male_prison_pop":
        new_order.append("male_total")
    # after each race pop column, insert its percentage
    for race in races:
        if col == f"{race}_pop_15to64":
            new_order.append(f"{race}_pct")

df = Prison_pop_reduced[new_order]

# # 5) Save the updated dataset
# output_path = "Prison_population_2015_2022_updated.csv"
# df.to_csv(output_path, index=False)

# # 6) Confirmation
# print(
#     f"Created 'female_total', 'male_total', and race pct columns; saved to:\n{output_path}"
# )
print(df.head(5))
# Out:
#    year state_abbr state_name  state_fips region division  total_pop_15to64  \
# 2  2022         AK     Alaska           2   West  Pacific          484376.0
# 3  2021         AK     Alaska           2   West  Pacific          486916.0
# 4  2020         AK     Alaska           2   West  Pacific          488623.0
# 5  2019         AK     Alaska           2   West  Pacific          493016.0
# 6  2018         AK     Alaska           2   West  Pacific          497876.0
#
#    female_pop_15to64  male_pop_15to64  aapi_pop_15to64  ...  \
# 2           224281.0         260095.0          44427.0  ...
# 3           225591.0         261325.0          44109.0  ...
# 4           226819.0         261804.0          43920.0  ...
# 5           229285.0         263731.0          43819.0  ...
# 6           231938.0         265938.0          43449.0  ...
#
#    total_prison_pop_rate  female_prison_pop_rate  male_prison_pop_rate  \
# 2             310.709036               33.440193            549.799112
# 3             320.999926               37.678808            565.579260
# 4             367.154227               43.647137            647.430903
# 5             361.448716               35.763351            644.596198
# 6             389.454402               37.510024            696.402921
#
#    female_total  male_total  aapi_pct  black_pct  latinx_pct  native_pct  \
# 2         410.0      4029.0      9.17       4.50        7.66       16.03
# 3         442.0      4197.0      9.06       4.48        7.51       15.96
# 4         419.0      4159.0      8.99       4.44        7.33       15.87
# 5         426.0      4049.0      8.89       4.42        7.26       15.71
# 6         379.0      4001.0      8.73       4.40        7.13       15.56
#
#    white_pct
# 2      62.64
# 3      62.99
# 4      63.37
# 5      63.72
# 6      64.18
#
# [5 rows x 53 columns]

# %%
# 2) Remove any duplicate column names – this keeps the first occurrence of each
df = df.loc[:, ~df.columns.duplicated()]

# # 3) Save the deduplicated dataset
# output_path = "Prison_population_2015_2022_updated.csv"
# df.to_csv(output_path, index=False)

# # 4) Confirmation
# print(f"Dropped duplicate columns and saved unique-column dataset to: {output_path}")
# print("Remaining columns:")
print(df.columns.tolist())
# Out:
# ['year', 'state_abbr', 'state_name', 'state_fips', 'region', 'division', 'total_pop_15to64', 'female_pop_15to64', 'male_pop_15to64', 'aapi_pop_15to64', 'aapi_pct', 'black_pop_15to64', 'black_pct', 'latinx_pop_15to64', 'latinx_pct', 'native_pop_15to64', 'native_pct', 'white_pop_15to64', 'white_pct', 'aapi_female_pop_15to64', 'black_female_pop_15to64', 'latinx_female_pop_15to64', 'native_female_pop_15to64', 'white_female_pop_15to64', 'aapi_male_pop_15to64', 'black_male_pop_15to64', 'latinx_male_pop_15to64', 'native_male_pop_15to64', 'white_male_pop_15to64', 'total_incarceration', 'total_incarceration_rate', 'held_in_jail', 'total_jail_pop', 'female_jail_pop', 'male_jail_pop', 'total_jail_pop_rate', 'female_jail_pop_rate', 'male_jail_pop_rate', 'total_prison_pop', 'female_prison_pop', 'female_total', 'male_prison_pop', 'male_total', 'total_prison_pop_rate', 'female_prison_pop_rate', 'male_prison_pop_rate']

# %%
# ------------------------------------------------------------------
# 2) List of columns to convert to integer
# ------------------------------------------------------------------
int_cols = [
    'total_pop_15to64', 'female_pop_15to64', 'male_pop_15to64',
    'aapi_pop_15to64', 'black_pop_15to64', 'latinx_pop_15to64',
    'native_pop_15to64', 'white_pop_15to64',
    'aapi_female_pop_15to64', 'black_female_pop_15to64',
    'latinx_female_pop_15to64', 'native_female_pop_15to64',
    'white_female_pop_15to64',
    'aapi_male_pop_15to64', 'black_male_pop_15to64',
    'latinx_male_pop_15to64', 'native_male_pop_15to64',
    'white_male_pop_15to64',
    'total_incarceration', 'held_in_jail', 'total_jail_pop',
    'female_jail_pop', 'male_jail_pop',
    'total_prison_pop', 'female_prison_pop',
    'female_total', 'male_prison_pop', 'male_total',
    'total_incarceration_rate', 'total_jail_pop_rate',	
    'female_jail_pop_rate',	'male_jail_pop_rate', 'total_prison_pop_rate',	
    'female_prison_pop_rate','male_prison_pop_rate'

]

# ------------------------------------------------------------------
# 3) Convert each column to integer
# ------------------------------------------------------------------
for col in int_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# # ------------------------------------------------------------------
# # 4) Save the cleaned dataset
# # ------------------------------------------------------------------
# output_path = 'Prison_population_2015_2022_updated.csv'
# df.to_csv(output_path, index=False)

# ------------------------------------------------------------------
# 5) Confirmation
# ------------------------------------------------------------------
# print(f"Converted columns to integer and saved to: {output_path}")
df[int_cols].head()
# Out:
#    total_pop_15to64  female_pop_15to64  male_pop_15to64  aapi_pop_15to64  \
# 2            484376             224281           260095            44427
# 3            486916             225591           261325            44109
# 4            488623             226819           261804            43920
# 5            493016             229285           263731            43819
# 6            497876             231938           265938            43449
#
#    black_pop_15to64  latinx_pop_15to64  native_pop_15to64  white_pop_15to64  \
# 2             21821              37108              77627            303393
# 3             21813              36553              77714            306727
# 4             21707              35801              77565            309630
# 5             21812              35800              77429            314156
# 6             21926              35475              77469            319557
#
#    aapi_female_pop_15to64  black_female_pop_15to64  ...  female_total  \
# 2                   22686                     8891  ...           410
# 3                   22457                     8889  ...           442
# 4                   22371                     8897  ...           419
# 5                   22373                     8997  ...           426
# 6                   22250                     9046  ...           379
#
#    male_prison_pop  male_total  total_incarceration_rate  total_jail_pop_rate  \
# 2             1430        4029                       986                  605
# 3             1478        4197                       952                  631
# 4             1695        4159                       936                  569
# 5             1700        4049                       907                  546
# 6             1852        4001                       879                  490
#
#    female_jail_pop_rate  male_jail_pop_rate  total_prison_pop_rate  \
# 2                   149                 999                    310
# 3                   158                1040                    320
# 4                   141                 941                    367
# 5                   150                 890                    361
# 6                   125                 808                    389
#
#    female_prison_pop_rate  male_prison_pop_rate
# 2                      33                   549
# 3                      37                   565
# 4                      43                   647
# 5                      35                   644
# 6                      37                   696
#
# [5 rows x 35 columns]

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# ------------------------------------------------------------------
# 1) Load death and population datasets
# ------------------------------------------------------------------
deaths = pd.read_csv("https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data_Manipulation/Cleaned_BJA_BJS_prison.csv", low_memory=False)
pop    = pd.read_csv("https://raw.githubusercontent.com/Ramil-cyber/Research_Linking_Analyzing_Deaths_US_Prisons/refs/heads/main/Data_Manipulation/Prison_population_2015_2022_updated.csv", low_memory=False)


# ------------------------------------------------------------------
# 2) Prepare death counts by year and state abbreviation
# ------------------------------------------------------------------
# Map full state names to USPS codes
full_to_abbr = {
    "ALABAMA": "AL", "ALASKA": "AK", "ARIZONA": "AZ", "ARKANSAS": "AR",
    "CALIFORNIA": "CA", "COLORADO": "CO", "CONNECTICUT": "CT", "DELAWARE": "DE",
    "DISTRICT OF COLUMBIA": "DC", "FLORIDA": "FL", "GEORGIA": "GA",
    "HAWAII": "HI", "IDAHO": "ID", "ILLINOIS": "IL", "INDIANA": "IN",
    "IOWA": "IA", "KANSAS": "KS", "KENTUCKY": "KY", "LOUISIANA": "LA",
    "MAINE": "ME", "MARYLAND": "MD", "MASSACHUSETTS": "MA", "MICHIGAN": "MI",
    "MINNESOTA": "MN", "MISSISSIPPI": "MS", "MISSOURI": "MO", "MONTANA": "MT",
    "NEBRASKA": "NE", "NEVADA": "NV", "NEW HAMPSHIRE": "NH", "NEW JERSEY": "NJ",
    "NEW MEXICO": "NM", "NEW YORK": "NY", "NORTH CAROLINA": "NC",
    "NORTH DAKOTA": "ND", "OHIO": "OH", "OKLAHOMA": "OK", "OREGON": "OR",
    "PENNSYLVANIA": "PA", "RHODE ISLAND": "RI", "SOUTH CAROLINA": "SC",
    "SOUTH DAKOTA": "SD", "TENNESSEE": "TN", "TEXAS": "TX", "UTAH": "UT",
    "VERMONT": "VT", "VIRGINIA": "VA", "WASHINGTON": "WA",
    "WEST VIRGINIA": "WV", "WISCONSIN": "WI", "WYOMING": "WY"
}
deaths['abbr'] = deaths['State_Name'].str.upper().map(full_to_abbr)
deaths['year'] = deaths['Reporting_Death_Year']

# Aggregate counts
df_deaths = (
    deaths
    .groupby(['year','abbr'], as_index=False)
    .size()
    .rename(columns={'size':'Deaths'})
)

# ------------------------------------------------------------------
# 3) Prepare population data (2015–2022)
# ------------------------------------------------------------------
pop = pop[pop['year'].between(2015,2022)]
# Ensure state codes match
pop = pop.rename(columns={'state_abbr':'abbr','state_name':'State_Name'})
# Keep necessary columns
pop = pop[['year','abbr','total_pop_15to64','State_Name']]

# ------------------------------------------------------------------
# 4) Merge deaths & population
# ------------------------------------------------------------------
df = df_deaths.merge(pop, on=['year','abbr'], how='left')

# ------------------------------------------------------------------
# 5) Add state centroids for label overlay
# ------------------------------------------------------------------
state_centroids = {
    'AL': {'lat':32.8067,'lon':-86.7911}, 'AK': {'lat':61.3707,'lon':-152.4044},
    'AZ': {'lat':33.7298,'lon':-111.4312}, 'AR': {'lat':34.9697,'lon':-92.3731},
    'CA': {'lat':36.1162,'lon':-119.6816}, 'CO': {'lat':39.0598,'lon':-105.3111},
    'CT': {'lat':41.5978,'lon':-72.7554}, 'DE': {'lat':39.3185,'lon':-75.5071},
    'DC': {'lat':38.8974,'lon':-77.0268}, 'FL': {'lat':27.7663,'lon':-81.6868},
    'GA': {'lat':33.0406,'lon':-83.6431}, 'HI': {'lat':21.0943,'lon':-157.4983},
    'ID': {'lat':44.2405,'lon':-114.4788}, 'IL': {'lat':40.3495,'lon':-88.9861},
    'IN': {'lat':39.8494,'lon':-86.2583}, 'IA': {'lat':42.0115,'lon':-93.2105},
    'KS': {'lat':38.5266,'lon':-96.7265}, 'KY': {'lat':37.6681,'lon':-84.6701},
    'LA': {'lat':31.1695,'lon':-91.8678}, 'ME': {'lat':44.6939,'lon':-69.3819},
    'MD': {'lat':39.0639,'lon':-76.8021}, 'MA': {'lat':42.2302,'lon':-71.5301},
    'MI': {'lat':43.3266,'lon':-84.5361}, 'MN': {'lat':45.6945,'lon':-93.9002},
    'MS': {'lat':32.7416,'lon':-89.6787}, 'MO': {'lat':38.4561,'lon':-92.2884},
    'MT': {'lat':46.9219,'lon':-110.4544}, 'NE': {'lat':41.1254,'lon':-98.2681},
    'NV': {'lat':38.3135,'lon':-117.0554}, 'NH': {'lat':43.4525,'lon':-71.5639},
    'NJ': {'lat':40.2989,'lon':-74.5210}, 'NM': {'lat':34.8405,'lon':-106.2485},
    'NY': {'lat':42.1657,'lon':-74.9481}, 'NC': {'lat':35.6301,'lon':-79.8064},
    'ND': {'lat':47.5289,'lon':-99.7840}, 'OH': {'lat':40.3888,'lon':-82.7649},
    'OK': {'lat':35.5653,'lon':-96.9289}, 'OR': {'lat':44.5720,'lon':-122.0709},
    'PA': {'lat':40.5908,'lon':-77.2098}, 'RI': {'lat':41.6809,'lon':-71.5118},
    'SC': {'lat':33.8569,'lon':-80.9450}, 'SD': {'lat':44.2998,'lon':-99.4388},
    'TN': {'lat':35.7478,'lon':-86.6923}, 'TX': {'lat':31.0545,'lon':-97.5635},
    'UT': {'lat':40.1500,'lon':-111.8624}, 'VT': {'lat':44.0459,'lon':-72.7107},
    'VA': {'lat':37.7693,'lon':-78.1699}, 'WA': {'lat':47.4009,'lon':-121.4905},
    'WV': {'lat':38.4912,'lon':-80.9545}, 'WI': {'lat':44.2685,'lon':-89.6165},
    'WY': {'lat':42.7560,'lon':-107.3025}
}
df['lat'] = df['abbr'].map(lambda s: state_centroids[s]['lat'])
df['lon'] = df['abbr'].map(lambda s: state_centroids[s]['lon'])

# ------------------------------------------------------------------
# 6) Build animated choropleth with pop in hover and slider for years
# ------------------------------------------------------------------
fig = px.choropleth(
    df,
    locations='abbr',
    locationmode='USA-states',
    color='Deaths',
    animation_frame='year',           # slider for 2015–2022
    hover_name='State_Name',
    hover_data={'Deaths':True,'total_pop_15to64':True},
    scope='usa',
    color_continuous_scale='Reds',
    labels={'Deaths':'Prisoner Deaths','total_pop_15to64':'Pop (15-64)'},
    title='US Prisoner Deaths & Population by State (2015–2022)'
)

# ------------------------------------------------------------------
# 7) Overlay state abbreviations without hoverinfo
# ------------------------------------------------------------------
fig.add_trace(go.Scattergeo(
    lon=df['lon'],
    lat=df['lat'],
    text=df['abbr'],
    mode='text',
    showlegend=False,
    hoverinfo='none',
    textfont=dict(size=10, color='black')
))

# ------------------------------------------------------------------
# 8) Layout tweaks
# ------------------------------------------------------------------
fig.update_layout(
    geo=dict(lakecolor='white',bgcolor='#F0F0F0'),
    margin=dict(l=0,r=0,t=60,b=0)
)

# ------------------------------------------------------------------
# 9) Export HTML and display
# ------------------------------------------------------------------
fig.write_html('interactive_prison_map.html', include_plotlyjs='cdn')
fig.show()
